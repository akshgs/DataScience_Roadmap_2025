# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# - Basic plotting (1–20) – line, bar, scatter, pie, histogram
#
# - Customization (21–40) – labels, legends, grids, styles, annotations
#
# - Subplots & layouts (41–55)
#
# -  Seaborn basics (56–75) – built-in datasets, scatterplot, countplot, etc.
#
# - Seaborn advanced (76–90) – pairplot, heatmap, categorical plots, regression

# %% [markdown]
# # 🧩 1–20: Matplotlib Basics

# %% [markdown]
# ## 1. Plot a simple line showing y = x² for x in range(0, 10).

# %%
x=np.arange(0,10)
y=x**2
plt.plot(x,y)
plt.show()

# %% [markdown]
# ## 2. Plot two lines (y = x and y = x²) on the same graph with labels and a legend.

# %%
x=np.arange(0,10)
y=x
y_1=x**2
plt.plot(x,y,label='Y = X')
plt.plot(x,y_1,label='Y = X^2')
plt.legend()
plt.show()

# %% [markdown]
# ## 3. Change the line color and style (dashed red line).

# %%
x=np.arange(0,10)
y=x**2
plt.plot(x,y,'r')
plt.show()

# %% [markdown]
# ## 4. Add axis labels and a title.

# %%
x=np.arange(0,10)
y=x
y_1=x**2
plt.plot(x,y,label='Y = X')
plt.plot(x,y_1,'r',label='Y = X^2')
plt.legend()
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.show()

# %% [markdown]
# ## 5. Create a bar chart for 5 fruits and their quantities.

# %%
fruit=['Apple','Banana','Orange','Mango','Pappaya']
qunti=np.random.randint(1,20,size=5)
plt.bar(fruit,qunti,width=0.8)
plt.show()

# %% [markdown]
# ## 6. Plot a horizontal bar chart for the same data

# %%
fruit=['Apple','Banana','Orange','Mango','Pappaya']
qunti=np.random.randint(1,20,size=5)
plt.barh(fruit,qunti)
plt.show()

# %% [markdown]
# ## 7. Draw a pie chart showing market share of 4 companies.

# %%
companies = ['Google', 'Apple', 'Microsoft', 'Amazon']
market_share = [30, 25, 20, 25]
plt.pie(market_share,labels=companies)
plt.show()

# %% [markdown]
# ## 8. Show percentage labels on each slice in the pie chart.

# %%
companies = ['Google', 'Apple', 'Microsoft', 'Amazon']
market_share = [30, 25, 20, 25]
plt.pie(market_share,labels=companies,autopct='%1.1f%%',startangle=90,shadow=True)
plt.show()

# %% [markdown]
# ## 9. Plot a histogram of 100 random numbers between 1–100

# %%
data=np.random.randint(1,101,size=100)
plt.hist(data,bins=10,color='skyblue',edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of 100 Random Numbers (1-100)')
plt.show()

# %% [markdown]
# ## 10. Increase the number of bins in your histogram to 20.

# %%
data=np.random.randint(1,101,size=100)
plt.hist(data,bins=20,color='skyblue',edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of 100 Random Numbers (1-100)')
plt.show()

# %% [markdown]
# ## 11. Create a scatter plot for random x and y values.

# %%
x=np.random.randint(1,100,size=50)
y=np.random.randint(1,100,size=50)
plt.scatter(x,y,color='purple',marker='o')
plt.title('Scatter Plot')
plt.xlabel('Xlabel')
plt.ylabel('Ylabel')
plt.show()

# %% [markdown]
# ## 12. Add gridlines to your scatter plot.

# %%
x=np.random.randint(1,100,size=50)
y=np.random.randint(1,100,size=50)
plt.scatter(x,y,color='purple',marker='o',alpha=0.5)
plt.title('Scatter Plot')
plt.xlabel('Xlabel')
plt.ylabel('Ylabel')
plt.grid(True)
plt.show()

# %% [markdown]
# ## 13. Change the figure size and DPI.

# %%
x=np.random.randint(1,100,size=50)
y=np.random.randint(1,100,size=50)
plt.figure(figsize=(10,6),dpi=200)
plt.scatter(x,y,color='purple',marker='o',alpha=0.5)
plt.title('Scatter Plot')
plt.xlabel('Xlabel')
plt.ylabel('Ylabel')
plt.grid(True)
plt.show()

# %% [markdown]
# ## 14. Save your plot as a PNG file.

# %%
x=np.random.randint(1,100,size=50)
y=np.random.randint(1,100,size=50)
plt.figure(figsize=(10,6),dpi=200)
plt.scatter(x,y,color='purple',marker='o',alpha=0.5)
plt.title('Scatter Plot')
plt.xlabel('Xlabel')
plt.ylabel('Ylabel')
plt.grid(True)
plt.savefig('scatter.png')
plt.show()

# %% [markdown]
# ## 15. Plot sine and cosine waves on the same axes

# %%
x=np.linspace(0,2*np.pi,100)
ysin=np.sin(x)
ycos=np.cos(x)
plt.figure(figsize=(10,6))
plt.plot(x,ysin,label='Sin(x)',color='blue')
plt.plot(x,ycos,label='Cos(x)',color='red')
plt.title('Sin and Cos Wave')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.show()

# %% [markdown]
# ## 16 Add a legend at the top-right corner.

# %%
x=np.linspace(0,2*np.pi,100)
ysin=np.sin(x)
ycos=np.cos(x)
plt.figure(figsize=(10,6))
plt.plot(x,ysin,label='Sin(x)',color='blue')
plt.plot(x,ycos,label='Cos(x)',color='red')
plt.title('Sin and Cos Wave')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ## 18. Use plt.subplot() to show 2 plots side by side.

# %%
x=np.linspace(0,2*np.pi,100)
ysin=np.sin(x)
ycos=np.cos(x)
plt.subplot(1,2,1)
plt.plot(x,ysin)
plt.title('Sin Value')
plt.subplot(1,2,2)
plt.title('Cos Value')
plt.plot(x,ycos)
plt.show()

# %% [markdown]
# ## 19. Show bar chart in one subplot and line plot in another.

# %%
categories = ['A', 'B', 'C', 'D', 'E']
values = [10, 15, 7, 12, 9]
x = np.arange(1, 11)
y = x ** 2

plt.figure(figsize=(8,6))
plt.subplot(1,2,1)
plt.plot(x,y)
plt.title('Line plot')
plt.xlabel("Xaxis")
plt.ylabel("yaxis")
plt.subplot(1,2,2)
plt.bar(categories,values)
plt.title('Barplot')
plt.xlabel("Xaxis")
plt.ylabel("yaxis")
plt.show()

# %% [markdown]
# ## 20. Display multiple lines with different styles and colors.

# %%
x=np.linspace(1,10,100)
y=np.sin(x)
y1=np.cos(x)
y2=np.sin(x)*np.cos(x)

plt.plot(x,y,color='red',marker='o',label='sin x')
plt.plot(x,y1,color='blue',linestyle='--',marker='s',label='cos x')
plt.plot(x,y2,color='green',linestyle='dashdot',marker='^',label='sin x * cos x')
plt.legend()
plt.show()

# %% [markdown]
# # 🎨 21–40: Customization & Styling

# %% [markdown]
# ## Use plt.style.use('ggplot') to apply a theme.

# %%
x=np.linspace(1,10,100)
y=np.sin(x)
y1=np.cos(x)
y2=np.sin(x)*np.cos(x)

plt.style.use('ggplot')

plt.plot(x,y,color='red',marker='o',label='sin x')
plt.plot(x,y1,color='blue',linestyle='--',marker='s',label='cos x')
plt.plot(x,y2,color='green',linestyle='dashdot',marker='^',label='sin x * cos x')
plt.legend()
plt.title('Multiple Lines with ggplot Style')
plt.show()

# %% [markdown]
# ## 22. Customize font size, color, and weight of labels

# %%
x=np.arange(0,10)
y=x
y_1=x**2
plt.plot(x,y,label='Y = X')
plt.plot(x,y_1,label='Y = X^2')

plt.style.use('default')

plt.xlabel('x axis',fontsize=14,color='purple',fontweight='bold')
plt.ylabel('y axis',fontsize=14,color='black',fontweight='bold')

plt.legend()
plt.show()

# %% [markdown]
# ## 23. Add a grid with dashed gray lines.

# %%
x=np.arange(0,10)
y=x
y_1=x**2
plt.figure(figsize=(4,3))
plt.grid(True)
plt.plot(x,y,label='Y = X',linestyle='dashed',color='gray')
plt.plot(x,y_1,label='Y = X^2')

# %% [markdown]
# ## 24. Add a vertical line (axvline) to indicate a threshold.

# %%
x=np.linspace(1,10,100)
y=np.sin(x)

plt.plot(x,y,color='red',label='X sine Value')
plt.axvline(x=5,color='pink',linestyle='--',linewidth='2',label='Thershold')
plt.legend()
plt.show()

# %% [markdown]
# ## 25. Annotate the maximum point on a line chart.

# %%
x=np.linspace(0,2*np.pi,100)
y=np.sin(x)

plt.plot(x,y,color='blue',label='Sin(x)')
max_index=np.argmax(x)
max_x=x[max_index]
max_y=y[max_index]

plt.scatter(max_x,max_y,color='red')

plt.annotate(f'Max: ({max_x:.2f}, {max_y:.2f})',
             xy=(max_x, max_y), 
             xytext=(max_x + 0.5, max_y + 0.1),
             arrowprops=dict(facecolor='black', shrink=0.05))

plt.xlabel('x')
plt.ylabel('y')
plt.title('Line Chart with Maximum Point Annotated')
plt.legend()
plt.grid(True)

# %% [markdown]
# ## 26. Use plt.text() to write custom notes on your plot

# %%
x=np.linspace(0,10,100)
y=np.sin(x)

plt.plot(x,y, color='skyblue',label='sin(X)')
plt.axvline(x=5,linestyle='--',label='Thershold')

plt.text(5.2,0,'Thershold=5',fontsize=12,color='red',fontweight='bold')
plt.text(1.6, 1, 'Peak Point', fontsize=12, color='green')
# Out:
# Text(1.6, 1, 'Peak Point')

# %% [markdown]
# ## 27. Change tick labels on the x-axis.

# %%
x=np.arange(5)
y=np.random.randint(10,50,size=5)

plt.bar(x,y,color='skyblue')
plt.xticks(ticks=x,labels=['Apple', 'Banana', 'Orange', 'Mango', 'Papaya'],fontsize=12,color='purple')
plt.xlabel('Fruit',fontsize=14)
plt.ylabel('Quantity',fontsize=14)
plt.title('Bar Chart with Custom X-axis Tick Labels')

plt.show()

# %% [markdown]
# ## 28. Rotate tick labels by 45°

# %%
fruits = ['Apple', 'Banana', 'Orange', 'Mango', 'Papaya']
quantity = [10, 15, 7, 12, 9]

plt.bar(quantity,fruits,color='yellow')
plt.xticks(rotation=40,fontsize=12,color='purple')
plt.xlabel('X',fontsize=20,color='red')
plt.ylabel('Y',fontsize=20,color='red')
plt.show()

# %% [markdown]
# ## 29. Add x and y ticks manually.

# %%
x=np.linspace(0,10,100)
y=np.sin(x)
plt.plot(x,y,color='lightgreen')
plt.xticks([0,2,4,6,8,10],labels=['zero','two','four','six','eight','ten'])
plt.yticks([-1,-0.5,0,0.5,1],labels=['minus one','minus zero point five','zero','point five','one'])
plt.show()

# %% [markdown]
# ## 30. Add a shadow to your bar chart.

# %%
import matplotlib.pyplot as plt

mark = [50, 25, 35, 42, 28]
sub = ['numpy', 'pandas', 'matplot', 'seaborn', 'eda']
plt.bar(sub, mark, color='gray', alpha=0.3, zorder=1)
plt.bar(sub, mark, color='skyblue', edgecolor='black', zorder=2)
plt.xlabel('Subjects', fontsize=12)
plt.ylabel('Marks', fontsize=12)
plt.title('Marks by Subject', fontsize=14)
plt.show()

# %% [markdown]
# ## 31. Use different markers in a scatter plot

# %%
x = np.linspace(1, 10, 10)
y1 = np.random.randint(10, 50, 10)
y2 = np.random.randint(20, 60, 10)
y3 = np.random.randint(30, 70, 10)
plt.scatter(x,y1,color='red',label='Group A',alpha=0.5)
plt.scatter(x,y2,color='orange',marker='h',label='Group B',alpha=0.5)
plt.scatter(x,y3,color='yellow',marker='p',label='group C',alpha=0.5)
plt.legend()
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %% [markdown]
# ## 33. Use transparency (alpha) to improve overlapping points.

# %%
x = np.linspace(1, 10, 10)
y1 = np.random.randint(10, 50, 10)
y2 = np.random.randint(20, 60, 10)
y3 = np.random.randint(30, 70, 10)
plt.scatter(x,y1,color='red',label='Group A',alpha=0.5)
plt.scatter(x,y2,color='blue',marker='h',label='Group B',alpha=0.5)
plt.scatter(x,y3,color='green',marker='p',label='group C',alpha=0.5)
plt.legend()
plt.xlabel('X axis')
plt.ylabel('Y')
plt.show()

# %% [markdown]
# ## 34. Add a border around your figure.

# %%
x = np.linspace(0, 10, 50)
y = np.sin(x)

plt.plot(x, y, color='blue')
plt.title("Plot with Border", fontsize=14)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
ax=plt.gca()
for spine in ax.spines.values():
    spine.set_edgecolor('black')
    spine.set_linewidth(3)

# %% [markdown]
# ## 35. Change the background color of the figure.

# %%
x = np.linspace(0, 10, 50)
y = np.sin(x)

plt.figure(facecolor='lavender')
plt.plot(x,y)

# %% [markdown]
# ## 36. Use tight layout to fix overlapping text.

# %%
x=np.linspace(1,10,100)
y1=np.sin(x)
y2=np.cos(x)
plt.figure(figsize=(6,4))
plt.subplot(1,2,1)
plt.plot(x,y1,color='red')
plt.title('Sine wave')
plt.subplot(1,2,2)
plt.plot(x,y2,color='green')
plt.title('Cos Wave')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 37. Draw vertical bars using ax.barh.

# %%
mark = [50, 25, 35, 42, 28]
sub = ['numpy', 'pandas', 'matplot', 'seaborn', 'eda']
fig,ax=plt.subplots()
ax.barh(sub,mark,color='lightblue',edgecolor='black')
ax.set_xlabel('mark')
ax.set_ylabel('Subject')
ax.set_title('horizontal bar')
plt.show()

# %% [markdown]
# ## 38. Add custom legend entries.

# %%
x=np.linspace(1,10,100)
y1=np.sin(x)
y2=np.cos(x)
plt.plot(x,y1,label='sine wave')
plt.plot(x,y2,label='Cos wave')
plt.legend(title='functions',fontsize=12,loc='best')
plt.show()

# %% [markdown]
# ## 39. Create stacked bar charts

# %%
subjects = ['Math', 'Physics', 'Chemistry', 'Biology', 'English']
marks_A = [50, 40, 60, 70, 45]   
marks_B = [30, 35, 25, 20, 40]
marks_C = [20, 25, 15, 10, 15]
x=np.arange(len(subjects))
plt.bar(x,marks_A,color='skyblue',label='Class A')
plt.bar(x,marks_B,color='lightgreen',label='Class B')
plt.bar(x,marks_C,color='orange',bottom=np.array(marks_A)+np.array(marks_B),label='Class C')
plt.xticks(x,subjects)
plt.xlabel('Subjects')
plt.ylabel('Mark')
plt.legend()
plt.show()

# %% [markdown]
# ## 40. Plot cumulative line using cumsum().

# %%
data=np.random.randint(1,10,size=10)
day=np.arange(1,11)
cs=np.cumsum(data)
plt.plot(day,cs,marker='o',color='blue',linestyle='-',label='Cumulative Sale')
plt.title('cumlative sale')
plt.xlabel('Day')
plt.ylabel('Cum Sale')
plt.legend()
plt.show()
