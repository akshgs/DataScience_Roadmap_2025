# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 41.Create a 2×2 grid of subplots

# %%
x=np.linspace(1,10,100)
y=np.cos(x)
y1=np.sin(x)
plt.figure(figsize=(4,2))
plt.subplot(1,2,1)
plt.title('Cos wave')
plt.plot(x,y,color='black',linestyle='--')
plt.subplot(1,2,2)
plt.title('Sine Wave')
plt.plot(x,y1,color='lightgreen')

plt.show()

# %% [markdown]
# ## 42. Share x-axis between subplots

# %%
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)
fig,(ax1,ax2)=plt.subplots(2,1,sharex=True,figsize=(8,6))

ax1.plot(x, y1, color='blue')
ax1.set_ylabel('sin(x)')
ax1.set_title('Shared X-axis Example')

ax2.plot(x,y2,color='red')
ax2.set_xlabel('cos(x)')
ax2.set_ylabel('cos')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 43. Add a main title for all subplots

# %%
x=np.linspace(1,10,100)
y=np.sin(x)
y1=np.cos(x)
fig,(ax1,ax2)=plt.subplots(2,1,sharex=True,figsize=(8,6))
fig.suptitle("Main Title for All Subplots", fontsize=16)
ax1.plot(x, y, color='blue')
ax1.set_ylabel('sin(x)')
ax1.set_title('Shared X-axis Example')

ax2.plot(x,y1,color='red')
ax2.set_xlabel('cos(x)')
ax2.set_ylabel('cos')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 44. Adjust space between subplots with plt.subplots_adjust.

# %%
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

fig, axs = plt.subplots(2, 1, figsize=(8,6))

axs[0].plot(x, y1)
axs[0].set_title("Sine Wave")

axs[1].plot(x, y2)
axs[1].set_title("Cosine Wave")

# Main title for all subplots
fig.suptitle("Main Title for All Subplots", fontsize=16)

# Adjust space between subplots
plt.subplots_adjust(
    top=0.88,   # space from top (for main title)
    bottom=0.1, # bottom margin
    left=0.1,   # left margin
    right=0.9,  # right margin
    hspace=0.4, # vertical space between subplots
    wspace=0.3  # horizontal space (if multiple columns)
)

plt.show()

# %% [markdown]
# ## 45. Use fig, ax = plt.subplots() and plot on multiple axes.

# %%
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

fig, axs = plt.subplots(2, 1, figsize=(8,6))

axs[0].plot(x, y1)
axs[0].set_title("Sine Wave")

axs[1].plot(x, y2)
axs[1].set_title("Cosine Wave")

# Main title for all subplots
fig.suptitle("Main Title for All Subplots", fontsize=16)

# Adjust space between subplots
plt.subplots_adjust(
    top=0.88,   # space from top (for main title)
    bottom=0.1, # bottom margin
    left=0.1,   # left margin
    right=0.9,  # right margin
    hspace=0.4, # vertical space between subplots
    wspace=0.3  # horizontal space (if multiple columns)
)
plt.subplots_adjust(hspace=0.4, wspace=0.3)
plt.show()

# %% [markdown]
# ## 46. Plot histograms on two subplots comparing male vs female data.

# %%
male_h=np.random.normal(175,7,200)
female_h=np.random.normal(162,6,200)
plt.figure(figsize=(4,3))
plt.subplot(1,2,1)
plt.hist(male_h,bins=7,alpha=0.7,edgecolor='black')
plt.title('male hieght')

plt.subplot(1,2,2)
plt.hist(female_h,bins=6,edgecolor='black',alpha=0.6,color='pink')
plt.title('female Height')
plt.show()

# %% [markdown]
# ## 47. Plot a heatmap using imshow() (without seaborn).

# %%
data = np.array([
    [50, 40, 60],   
    [40, 35, 45], 
    [60, 25, 55],   
    [70, 20, 65],   
    [45, 40, 30]
])
subjects = ['Math', 'Physics', 'Chemistry', 'Biology', 'English']
classes = ['Class A', 'Class B', 'Class C']
plt.imshow(data, cmap='viridis', interpolation='nearest')
plt.colorbar(label='Marks')
plt.show()

# %% [markdown]
# ## 48. Combine line and bar plots in one figure using two axes (twinx).

# %% [markdown]
# ## 48. Combine line and bar plots in one figure using two axes (twinx).

# %%
data=['apple','orange','banana','mango','pappaya']
count=np.random.randint(6,22,5)
quli=np.random.randint(1,10,5)
fig,ax1=plt.subplots(figsize=(8,4))
bar = ax1.bar(data, count, color='skyblue', edgecolor='black', label='Count')
ax1.set_xlabel('Fruits')
ax1.set_ylabel('Count', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

ax2=ax1.twinx()
line=ax2.plot(data,quli,color='red',marker='o',label='quality')
ax2.set_ylabel('Quality',color='red')
ax2.tick_params(axis='y',labelcolor='red')

handles = [bar, line[0]]
labels = ['Count', 'Quality']
ax1.legend(handles, labels, loc='upper left')

plt.title('Count vs Quality for Fruits (Bar + Line with twinx)')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 49. Save each subplot as a separate image.

# %%
data=['apple','orange','banana','mango','pappaya']
count=np.random.randint(6,22,5)
quli=np.random.randint(1,10,5)

plt.subplot(1,2,1)
plt.bar(data,count,color='pink',edgecolor='black')
plt.xlabel('Frutis')
plt.title('conut')
plt.xticks(rotation=30)

plt.subplot(1,2,2)
plt.bar(data,count,color='lightgreen',edgecolor='black')
plt.title('quality')
plt.xlabel('fruit')

plt.tight_layout()
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# ## 50. Turn off axis for one subplot.

# %%
data=['apple','orange','banana','mango','pappaya']
count=np.random.randint(6,22,5)
quli=np.random.randint(1,10,5)

plt.subplot(1,2,1)
plt.bar(data,count,color='pink',edgecolor='black')
plt.xlabel('Frutis')
plt.title('conut')

plt.xticks(rotation=30)

plt.subplot(1,2,2)
plt.bar(data,count,color='lightgreen',edgecolor='black')
plt.title('quality')
plt.xlabel('fruit')

plt.tight_layout()
plt.xticks(rotation=30)

plt.gca().axis('off')
plt.show()

# %% [markdown]
# ## 51. Display colorbar in a heatmap

# %%
data=np.random.randint(0,100,(5,5))
plt.imshow(data,cmap='viridis',interpolation='nearest')
plt.colorbar(label='value')
plt.show()

# %% [markdown]
# ## 52. Add an inset zoom plot inside a larger plot.

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

# Sample data
x = np.linspace(0, 10, 500)
y = np.sin(x) + 0.2*np.random.randn(500)  # sine wave with noise

# Main plot
fig, ax = plt.subplots(figsize=(8, 5))
ax.plot(x, y, color='blue')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Main Plot with Zoom Inset')

# Add an inset axes (width=30%, height=30% of the main plot)
axins = inset_axes(ax, width="30%", height="30%", loc='upper right')

# Plot the same data in the inset
axins.plot(x, y, color='red')

# Set limits for zoom region
x1, x2 = 2, 4   # zoomed x-range
y1, y2 = -1, 1  # zoomed y-range
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)

# Optional: remove ticks for clarity
axins.set_xticks([])
axins.set_yticks([])

# Draw a rectangle on the main plot showing the zoom area
from mpl_toolkits.axes_grid1.inset_locator import mark_inset
mark_inset(ax, axins, loc1=2, loc2=4, fc="none", ec="0.5")

plt.show()

# %% [markdown]
# ## 53. Plot two time series with shared x-axis.
